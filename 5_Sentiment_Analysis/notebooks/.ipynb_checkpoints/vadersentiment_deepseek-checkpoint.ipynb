# %% [markdown]
# import sys
# !{sys.executable} -m pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize VADER so we can use it later
sentimentAnalyser = SentimentIntensityAnalyzer()

# %%
import pandas as pd
pd.options.display.max_colwidth = 400

# %%
# test a sentence
sentimentAnalyser.polarity_scores("I like the Marvel movies")
# Out:
# {'neg': 0.0, 'neu': 0.361, 'pos': 0.639, 'compound': 0.6486}

# %%
# 1. Load all .txt files from the folder

import os

# Path to the folder of news articles
folder_path = '../Corpus_deepseek'

# List all .txt files in the folder
file_names = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Read each file
texts = []
file_ids = []

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
        texts.append(content)
        file_ids.append(file_name)  # Keep track of which file is which

# %%
# 2. Run VADER sentiment analysis on each article

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

sentiments = []
for text in texts:
    score = analyzer.polarity_scores(text)
    sentiments.append(score)

# %%
# 3. combine into one dataframe

import pandas as pd

df = pd.DataFrame({
    'filename': file_ids,
    'text': texts,
    'sentiment': sentiments
})

# Optional: Extract compound sentiment score
df['compound'] = df['sentiment'].apply(lambda x: x['compound'])

# Preview the results
print(df[['filename', 'compound']].head())
# Out:
#                                             filename  compound
# 0  What_is_DeepSeek,_the_Chinese_AI_startup_that_...    0.9984
# 1  Chinese_AI_disrupter_DeepSeek_claims_top_spot_...    0.8481
# 2  Which_countries_have_banned_DeepSeek_and_why?.txt    0.8846
# 3          Global_AI_rivalry_is_a_dangerous_game.txt   -0.8705
# 4  DeepSeek_just_blew_up_the_AI_industry’s_narrat...    0.9271

# %%
# 4. save to CSV
df.to_csv('deepseek_vadersentiment_results.csv', index=False)

# %% [markdown]
# Plot Sentiment Over Time
# We can plot how texts’ sentiment fluctuates over time
# ✅ Goal:
# I want to plot sentiment over time, grouped by source (e.g., newspaper), using:
#
# Sentiment scores from .txt files
#
# Metadata (source + date) from your CSV
#
# ✅ Assumptions:
# Each .txt file is a news article with a filename like title1.txt, title2.txt, etc.
#
# The metadata CSV has at least:
#
# A filename column (e.g., title1.txt)
#
# A source column (e.g., BBC, CNN)
#
# A date column (e.g., 2023-06-01), though some dates are missing.

# %%
# step 1
import pandas as pd

# Load data from two csv files
sentiment_df = pd.read_csv("deepseek_vadersentiment_results.csv")
meta_df = pd.read_csv("../metadata_all_texts.csv")
print(sentiment_df.head())
print(meta_df.head())
# Out:
#                                             filename  \
# 0  What_is_DeepSeek,_the_Chinese_AI_startup_that_...
# 1  Chinese_AI_disrupter_DeepSeek_claims_top_spot_...
# 2  Which_countries_have_banned_DeepSeek_and_why?.txt
# 3          Global_AI_rivalry_is_a_dangerous_game.txt
# 4  DeepSeek_just_blew_up_the_AI_industry’s_narrat...
#
#                                                 text  \
# 0  CNN —\n\nA surprisingly efficient and powerful...
# 1  Chinese artificial intelligence (AI) start-up ...
# 2  DeepSeek is banned on government devices in So...
# 3  \nJulian Gewirtz PublishedJUL 29 2025 167 Prin...
# 4  A version of this story appeared in CNN Busine...
#
#                                            sentiment  compound
# 0  {'neg': 0.035, 'neu': 0.848, 'pos': 0.117, 'co...    0.9984
# 1  {'neg': 0.033, 'neu': 0.902, 'pos': 0.065, 'co...    0.8481
# 2  {'neg': 0.04, 'neu': 0.91, 'pos': 0.05, 'compo...    0.8846
# 3  {'neg': 0.098, 'neu': 0.809, 'pos': 0.093, 'co...   -0.8705
# 4  {'neg': 0.03, 'neu': 0.924, 'pos': 0.046, 'com...    0.9271
#                                          title            author        date  \
# 0                    China’s DeepSeek Surprise       Matteo Wong  2025-01-27
# 1                     What Is AI Distillation?       Damon Beres  2025-02-07
# 2                    The DeepSeek Wake-Up Call       Matteo Wong  2025-01-30
# 3  DeepSeek’s Chatbot Has an Important Message  James Surowiecki  2025-01-31
# 4          Is DeepSeek China’s Sputnik Moment?      John Cassidy  2025-02-03
#
#            source                                                url  \
# 0    The Atlantic  https://www.theatlantic.com/technology/archive...
# 1    The Atlantic  https://www.theatlantic.com/newsletters/archiv...
# 2    The Atlantic  https://www.theatlantic.com/newsletters/archiv...
# 3    The Atlantic  https://www.theatlantic.com/ideas/archive/2025...
# 4  The New Yorker  https://www.newyorker.com/news/the-financial-p...
#
#                                           filename
# 0                    China’s_DeepSeek_Surprise.txt
# 1                     What_Is_AI_Distillation?.txt
# 2                    The_DeepSeek_Wake-Up_Call.txt
# 3  DeepSeek’s_Chatbot_Has_an_Important_Message.txt
# 4          Is_DeepSeek_China’s_Sputnik_Moment?.txt

# %%
# step 2
# Merge two csv files on 'filename'
merged_df = pd.merge(sentiment_df, metadata_df, on="filename")

# Convert date column
merged_df['date'] = pd.to_datetime(merged_df['date'])

# %%
# step 3: Group and Plot
# Option A: Use Altair

import altair as alt

grouped = merged_df.groupby(['date', 'source'])['compound'].mean().reset_index()

chart = alt.Chart(grouped).mark_line(point=True).encode(
    x='date:T',
    y='compound:Q',
    color='source:N',
    tooltip=['date:T', 'source:N', 'compound:Q']
).properties(
    title='Sentiment Over Time by Source',
    width=800,     # ⬅️ expand width here (default is ~400)
    height=400     # ⬅️ optional
)

chart.display()
# Out:
# alt.Chart(...)

# %%
# zoom in on particular time period
chart_interactive = alt.Chart(grouped).mark_line(point=True).encode(
    x=alt.X('date:T', scale=alt.Scale(domain=('2025-01-26', '2025-02-23'))),  # initial zoom range
    y='compound:Q',
    color='source:N',
    tooltip=['date:T', 'source:N', 'compound:Q']
).properties(
    title='Interactive Sentiment Chart (Initial Zoom: Jan 26 – Feb 23)',
    width=800,
    height=400
).interactive()  # Enables zooming and panning

chart_interactive.display()
# Out:
# alt.Chart(...)

# %% [markdown]
#  Observations (summarized):
# Most sentiment scores are between 0.0 and 1.0 → generally positive.
# High density of articles between Jan 26 and Feb 23 → suggests an important event (likely stock-related).
# Many articles have strong positive sentiment (0.6–1.0).
# A few articles have very negative sentiment (≤ -0.8) → potential outliers or critical views.

# %% [markdown]
# import sys
# !{sys.executable} -m pip install matplotlib

# %%
# option B this could be conducted in another enviroment
import matplotlib.pyplot as plt

grouped = merged_df.groupby(['date', 'source'])['compound'].mean().reset_index()

plt.figure(figsize=(12, 6))

for source in grouped['source'].unique():
    subset = grouped[grouped['source'] == source]
    plt.plot(subset['date'], subset['compound'], label=source)

plt.title('Sentiment Over Time by Source')
plt.xlabel('Date')
plt.ylabel('Average Sentiment (compound score)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Find articles with very negative sentiment
very_negative = merged_df[merged_df['compound'] <= -0.8]

# Show their filenames, sources, dates, and compound scores
very_negative[['filename', 'source', 'date', 'compound']]
# Out:
#                                               filename              source  \
# 3            Global_AI_rivalry_is_a_dangerous_game.txt     Financial Times
# 11   What_questions_will_China's_DeepSeek_not_answe...                  DW
# 21   DeepSeek:_Is_China's_AI_tool_as_good_as_it_see...                 BBC
# 32   First_Thing:_Donald_Trump_calls_China’s_DeepSe...        The Guardian
# 42   South_Korea_Bans_Downloads_of_DeepSeek,_the_Ch...  THe New York Times
# 63   DeepSeek_has_ripped_away_AI’s_veil_of_mystique...        The Guardian
# 110  Diving_into_DeepSeek:_inside_the_7_February_Gu...        The Guardian
#
#           date  compound
# 3   2025-07-29   -0.8705
# 11  2025-01-31   -0.9249
# 21  2025-01-27   -0.8249
# 32  2025-01-28   -0.9913
# 42  2025-02-17   -0.8442
# 63  2025-02-02   -0.8572
# 110 2025-02-05   -0.8556

# %%
# Select specific columns
very_negative_subset = very_negative[['filename', 'source', 'date', 'compound','text']]

# Save to CSV
very_negative_subset.to_csv('very_negative_texts.csv', index=False)

# %%
import os
import shutil

# Step 1: List of filenames to include
filenames = [
    "Global_AI_rivalry_is_a_dangerous_game.txt",
    "What_questions_will_China's_DeepSeek_not_answer?_–.txt",
    "DeepSeek:_Is_China's_AI_tool_as_good_as_it_seems?.txt",
	"First_Thing:_Donald_Trump_calls_China’s_DeepSeek_A.txt",
	"South_Korea_Bans_Downloads_of_DeepSeek,_the_Chines.txt",
	"DeepSeek_has_ripped_away_AI’s_veil_of_mystique._Th.txt",
	"Diving_into_DeepSeek:_inside_the_7_February_Guardi.txt"
   
]

# Step 2: Set up paths
source_folder = "../Corpus_deepseek"              # change this to your source folder
destination_folder = "./negative_DeepSeek_texts"    # name of your new folder

# Step 3: Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Step 4: Copy matching files to the new folder
for filename in filenames:
    source_path = os.path.join(source_folder, filename)
    destination_path = os.path.join(destination_folder, filename)
    
    try:
        shutil.copy(source_path, destination_path)
        print(f"Copied: {filename}")
    except FileNotFoundError:
        print(f"❌ File not found: {filename}")
# Out:
# Copied: Global_AI_rivalry_is_a_dangerous_game.txt
# Copied: What_questions_will_China's_DeepSeek_not_answer?_–.txt
# Copied: DeepSeek:_Is_China's_AI_tool_as_good_as_it_seems?.txt
# Copied: First_Thing:_Donald_Trump_calls_China’s_DeepSeek_A.txt
# Copied: South_Korea_Bans_Downloads_of_DeepSeek,_the_Chines.txt
# Copied: DeepSeek_has_ripped_away_AI’s_veil_of_mystique._Th.txt
# Copied: Diving_into_DeepSeek:_inside_the_7_February_Guardi.txt
